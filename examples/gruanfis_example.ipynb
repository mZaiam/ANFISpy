# %% [markdown]
# <a href="https://colab.research.google.com/github/mZaiam/ANFISpy/blob/main/examples/gruanfis_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `GRUANFIS` tutorial

# %%
# !pip install anfispy
# Out:
# Collecting anfispy
#   Downloading anfispy-1.2.1-py3-none-any.whl.metadata (434 bytes)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from anfispy) (2.11.0+cpu)
# Requirement already satisfied: numpy>=2.1.3 in /usr/local/lib/python3.13/dist-packages (from anfispy) (2.1.3)
# Requirement already satisfied: matplotlib>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from anfispy) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (2025.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->anfispy) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.5.1->anfispy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.5.1->anfispy) (3.0.3)
# Downloading anfispy-1.2.1-py3-none-any.whl (22 kB)
# Installing collected packages: anfispy
# Successfully installed anfispy-1.2.1

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

from ANFISpy import GRUANFIS

# %% [markdown]
# Generating synthetic data.

# %%
time = np.linspace(0, 1, 500)
data = np.sin(time * 50) * np.exp(- time) + 0.1 * np.random.random(500)

plt.figure(figsize=(9, 4))
plt.scatter(time, data)
plt.show()

# %% [markdown]
# Splitting the data into sequences.

# %%
x, y, t = [], [], []
seq_len = 10

for i in range(len(data) - seq_len):
    x.append(data[i : i + seq_len])
    y.append(data[i + seq_len])
    t.append(time[i + seq_len])

x = torch.FloatTensor(np.array(x)).unsqueeze(-1)
y = torch.FloatTensor(np.array(y)).unsqueeze(-1)
t = np.array(t)

train_size = int(0.7 * len(x))
val_size = int(0.15 * len(x))

x_train, y_train, t_train = x[:train_size], y[:train_size], t[:train_size]
x_val, y_val, t_val = x[train_size:train_size + val_size], y[train_size:train_size + val_size], t[train_size:train_size + val_size]
x_test, y_test, t_test = x[train_size + val_size:], y[train_size + val_size:], t[train_size + val_size:]

# %% [markdown]
# Instatiating RANFIS. Note that this is a GRU based ANFIS, so it is best suited for time series.

# %%
n_vars = 1
mf_names = [['L', 'M', 'H']]

variables = {
    'inputs': {
        'n_sets': [5],
        'uod': n_vars * [(0, 1)],
        'var_names': ['t'],
        'mf_names': n_vars * mf_names,
    },
    'output': {
        'var_names': 'out',
        'n_classes': 1,
    },
}

gruanfis = GRUANFIS(variables, 'bell', seq_len, output_activation=nn.Identity())

# %% [markdown]
# Training the model.

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(gruanfis.parameters(), lr=0.01)

epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs, _ = gruanfis(x_train)
    loss_train = criterion(outputs[:, -1, :] , y_train)
    loss_train.backward()
    optimizer.step()

    gruanfis.eval()
    with torch.no_grad():
        outputs, _ = gruanfis(x_val)
        loss_val = criterion(outputs[:, -1, :] , y_val)

    if epoch % 50 == 0:
        print(f'Epoch {epoch} | Train Loss: {loss_train.item():.5f} | Validation Loss: {loss_val.item():.5f}')
# Out:
# Epoch 0 | Train Loss: 0.56456 | Validation Loss: 0.52600
# Epoch 50 | Train Loss: 0.01443 | Validation Loss: 0.00816
# Epoch 100 | Train Loss: 0.00655 | Validation Loss: 0.00421
# Epoch 150 | Train Loss: 0.00546 | Validation Loss: 0.00346
# Epoch 200 | Train Loss: 0.00504 | Validation Loss: 0.00316
# Epoch 250 | Train Loss: 0.00465 | Validation Loss: 0.00289
# Epoch 300 | Train Loss: 0.00391 | Validation Loss: 0.00251
# Epoch 350 | Train Loss: 0.00248 | Validation Loss: 0.00194
# Epoch 400 | Train Loss: 0.00203 | Validation Loss: 0.00178
# Epoch 450 | Train Loss: 0.00187 | Validation Loss: 0.00169
# Epoch 500 | Train Loss: 0.00178 | Validation Loss: 0.00166
# Epoch 550 | Train Loss: 0.00172 | Validation Loss: 0.00163
# Epoch 600 | Train Loss: 0.00166 | Validation Loss: 0.00160
# Epoch 650 | Train Loss: 0.00162 | Validation Loss: 0.00157
# Epoch 700 | Train Loss: 0.00158 | Validation Loss: 0.00155
# Epoch 750 | Train Loss: 0.00154 | Validation Loss: 0.00153
# Epoch 800 | Train Loss: 0.00151 | Validation Loss: 0.00150
# Epoch 850 | Train Loss: 0.00148 | Validation Loss: 0.00148
# Epoch 900 | Train Loss: 0.00145 | Validation Loss: 0.00145
# Epoch 950 | Train Loss: 0.00142 | Validation Loss: 0.00142

# %% [markdown]
# Plotting the model outputs.

# %%
gruanfis.eval()

with torch.no_grad():
    train_predictions = gruanfis(x_train)[0][:, -1, :].numpy().flatten()
    val_predictions = gruanfis(x_val)[0][:, -1, :].numpy().flatten()
    test_predictions = gruanfis(x_test)[0][:, -1, :].numpy().flatten()

fig, axes = plt.subplots(3, 2, figsize=(14, 12))

axes[0, 0].scatter(t_train, y_train.numpy(), label='Data', alpha=0.5)
axes[0, 0].scatter(t_train, train_predictions, label='Predictions')
axes[0, 0].legend()
axes[0, 0].set_title('Train Fit')

axes[0, 1].scatter(t_train, y_train.numpy().flatten() - train_predictions)
axes[0, 1].axhline(0, c='red', linestyle='--')
axes[0, 1].set_title('Train Error')

axes[1, 0].scatter(t_val, y_val.numpy(), label='Data', alpha=0.5)
axes[1, 0].scatter(t_val, val_predictions, label='Predictions')
axes[1, 0].legend()
axes[1, 0].set_title('Validation Predictions')

axes[1, 1].scatter(t_val, y_val.numpy().flatten() - val_predictions)
axes[1, 1].axhline(0, c='red', linestyle='--')
axes[1, 1].set_title('Validation Error')

axes[2, 0].scatter(t_test, y_test.numpy(), label='Data', alpha=0.5)
axes[2, 0].scatter(t_test, test_predictions, label='Predictions')
axes[2, 0].legend()
axes[2, 0].set_title('Test Predictions')

axes[2, 1].scatter(t_test, y_test.numpy().flatten() - test_predictions)
axes[2, 1].axhline(0, c='red', linestyle='--')
axes[2, 1].set_title('Test Error')

plt.tight_layout()
plt.show()
