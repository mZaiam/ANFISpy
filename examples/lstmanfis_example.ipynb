# %% [markdown]
# # `LSTMANFIS` tutorial

# %%
import torch 
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

from ANFISpy import LSTMANFIS

# %% [markdown]
# Generating synthetic data.

# %%
time = np.linspace(0, 1, 500)
data = np.sin(time * 50) * np.exp(- time) + 0.1 * np.random.random(500)

plt.figure(figsize=(9, 4))
plt.scatter(time, data)
plt.show()

# %% [markdown]
# Splitting the data into sequences.

# %%
x, y, t = [], [], []
seq_len = 10

for i in range(len(data) - seq_len): 
    x.append(data[i : i + seq_len])  
    y.append(data[i + seq_len])      
    t.append(time[i + seq_len])
    
x, y, t = np.array(x), np.array(y), np.array(t)
x = torch.FloatTensor(x).unsqueeze(2)
y = torch.FloatTensor(y).unsqueeze(1)

train_size = int(0.7 * len(x))
val_size = int(0.15 * len(x))

x_train, y_train, t_train = x[:train_size], y[:train_size], t[:train_size]
x_val, y_val, t_val = x[train_size:train_size+val_size], y[train_size:train_size+val_size], t[train_size:train_size+val_size]
x_test, y_test, t_test = x[train_size+val_size:], y[train_size+val_size:], t[train_size+val_size:]

# %% [markdown]
# Instatiating LSTM-ANFIS. Note that this is a LSTM based ANFIS, so it is best suited for time series.

# %%
n_vars = 1
mf_names = [['L', 'M', 'H']]

variables = {
    'inputs': {
        'n_sets': [5],
        'uod': n_vars * [(0, 1)],
        'var_names': ['t'],
        'mf_names': n_vars * mf_names,
    },
    'output': {
        'var_names': 'out',
        'n_classes': 1,
    },
}

lstmanfis = LSTMANFIS(variables, 'bell', output_activation=nn.Identity())

# %% [markdown]
# Training the model.

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(lstmanfis.parameters(), lr=0.01)

epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs, _ = lstmanfis(x_train)
    loss_train = criterion(outputs, y_train)
    loss_train.backward()
    optimizer.step()
    
    lstmanfis.eval()
    with torch.no_grad():
        outputs, _ = lstmanfis(x_val)
        loss_val = criterion(outputs, y_val)
    
    if epoch % 50 == 0:
        print(f'Epoch {epoch} | Train Loss: {loss_train.item():.5f} | Validation Loss: {loss_val.item():.5f}')
# Out:
# Epoch 0 | Train Loss: 1.46729 | Validation Loss: 0.89662
# Epoch 50 | Train Loss: 0.02804 | Validation Loss: 0.02873
# Epoch 100 | Train Loss: 0.00775 | Validation Loss: 0.00578
# Epoch 150 | Train Loss: 0.00615 | Validation Loss: 0.00392
# Epoch 200 | Train Loss: 0.00553 | Validation Loss: 0.00338
# Epoch 250 | Train Loss: 0.00520 | Validation Loss: 0.00311
# Epoch 300 | Train Loss: 0.00501 | Validation Loss: 0.00296
# Epoch 350 | Train Loss: 0.00488 | Validation Loss: 0.00287
# Epoch 400 | Train Loss: 0.00478 | Validation Loss: 0.00279
# Epoch 450 | Train Loss: 0.00469 | Validation Loss: 0.00272
# Epoch 500 | Train Loss: 0.00460 | Validation Loss: 0.00267
# Epoch 550 | Train Loss: 0.00450 | Validation Loss: 0.00261
# Epoch 600 | Train Loss: 0.00434 | Validation Loss: 0.00254
# Epoch 650 | Train Loss: 0.00353 | Validation Loss: 0.00223
# Epoch 700 | Train Loss: 0.00201 | Validation Loss: 0.00178
# Epoch 750 | Train Loss: 0.00190 | Validation Loss: 0.00173
# Epoch 800 | Train Loss: 0.00185 | Validation Loss: 0.00171
# Epoch 850 | Train Loss: 0.00182 | Validation Loss: 0.00168
# Epoch 900 | Train Loss: 0.00180 | Validation Loss: 0.00165
# Epoch 950 | Train Loss: 0.00178 | Validation Loss: 0.00163

# %% [markdown]
# Plotting the model outputs.

# %%
lstmanfis.eval()

with torch.no_grad():
    train_predictions = lstmanfis(x_train)[0].numpy().flatten()
    val_predictions = lstmanfis(x_val)[0].numpy().flatten()
    test_predictions = lstmanfis(x_test)[0].numpy().flatten()

fig, axes = plt.subplots(3, 2, figsize=(14, 12))

axes[0, 0].scatter(t_train, y_train.numpy(), label='Data', alpha=0.5)
axes[0, 0].scatter(t_train, train_predictions, label='Predictions')
axes[0, 0].legend()
axes[0, 0].set_title('Train Fit')

axes[0, 1].scatter(t_train, y_train.numpy().flatten() - train_predictions)
axes[0, 1].axhline(0, c='red', linestyle='--')
axes[0, 1].set_title('Train Error')

axes[1, 0].scatter(t_val, y_val.numpy(), label='Data', alpha=0.5)
axes[1, 0].scatter(t_val, val_predictions, label='Predictions')
axes[1, 0].legend()
axes[1, 0].set_title('Validation Predictions')

axes[1, 1].scatter(t_val, y_val.numpy().flatten() - val_predictions)
axes[1, 1].axhline(0, c='red', linestyle='--')
axes[1, 1].set_title('Validation Error')


axes[2, 0].scatter(t_test, y_test.numpy(), label='Data', alpha=0.5)
axes[2, 0].scatter(t_test, test_predictions, label='Predictions')
axes[2, 0].legend()
axes[2, 0].set_title('Test Predictions')

axes[2, 1].scatter(t_test, y_test.numpy().flatten() - test_predictions)
axes[2, 1].axhline(0, c='red', linestyle='--')
axes[2, 1].set_title('Test Error')

plt.tight_layout()
plt.show()
