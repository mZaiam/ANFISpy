# %% [markdown]
# <a href="https://colab.research.google.com/github/mZaiam/ANFISpy/blob/main/examples/canfis_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `ANFISpy` tutorial

# %%
# !pip install anfispy
# Out:
# Collecting anfispy
#   Downloading anfispy-1.2.1-py3-none-any.whl.metadata (434 bytes)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from anfispy) (2.11.0+cpu)
# Requirement already satisfied: numpy>=2.1.3 in /usr/local/lib/python3.13/dist-packages (from anfispy) (2.1.3)
# Requirement already satisfied: matplotlib>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from anfispy) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.0->anfispy) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.5.1->anfispy) (2025.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->anfispy) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.5.1->anfispy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.5.1->anfispy) (3.0.3)
# Downloading anfispy-1.2.1-py3-none-any.whl (22 kB)
# Installing collected packages: anfispy
# Successfully installed anfispy-1.2.1

# %% [markdown]
# Here, we are going to give a brief tutorial about the `CANFIS` model usage.

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from ANFISpy import CANFIS
from ANFISpy import HamacherAND, ProdAND

# %% [markdown]
# ## Regression

# %% [markdown]
# Loading the dataset:

# %%
SEED = 10
torch.manual_seed = SEED

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"

df = pd.read_csv(url)
df = df.dropna()

FEATURES = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']
TARGET = ['body_mass_g']

x = df[FEATURES].values
y = df[TARGET].values

# %% [markdown]
# Train, test and validation split:

# %%
x, index = np.unique(x, axis=0, return_index=True)
y = y[index]

x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.4, random_state=SEED)
x_test, x_val, y_test, y_val = train_test_split(x_temp, y_temp, test_size=0.5, random_state=SEED)

x_train = torch.tensor(x_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
x_test = torch.tensor(x_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)
x_val = torch.tensor(x_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)

x_train_max = x_train.max(dim=0, keepdim=True)[0]
y_train_max = y_train.max(dim=0, keepdim=True)[0]
x_test_max = x_test.max(dim=0, keepdim=True)[0]
y_test_max = y_test.max(dim=0, keepdim=True)[0]
x_val_max = x_val.max(dim=0, keepdim=True)[0]
y_val_max = y_val.max(dim=0, keepdim=True)[0]

x_train /= x_train_max
y_train /= y_train_max
x_test /= x_test_max
y_test /= y_test_max
x_val /= x_val_max
y_val /= y_val_max

# %% [markdown]
# Creating the DataLoaders:

# %%
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# The model is instantiated with a dictionary, containing information about the `inputs` and `output`. The `inputs` key has the following keys:
# - `n_sets`: list with number of fuzzy set of each input variable;
# - `uod`: list with tuples/lists representing the universe of discourse of each input variable;
# - `var_names`: list with strings for the name of each input variable;
# - `mf_names`: list with strings for the name of the fuzzy sets associated to each input variable.
#
# The `output` has similar keys:
# - `var_names`: string for the name of the output variable, or a list of strings, if the model is a classifier;
# - `n_classes`: if the model is a regressor, set the value to 1.
#
# This dictionary is then passed to instantiate the model, which is going to use the information in it for plots and model visualization. Here, the `HamacherAND` generalized t-norm is going to be used. Also, one can handle the NN hyperparameters with the arguments `nn_layers`, `nn_neurons` and `nn_activation`.

# %%
n_vars = 3
mf_names = [['L', 'M', 'H']]
device = 'cuda' if torch.cuda.is_available() else 'cpu'

and_op = HamacherAND(r=1)

variables = {
    'inputs': {
        'n_sets': [3, 3, 3],
        'uod': n_vars * [(0, 1)],
        'var_names': FEATURES,
        'mf_names': n_vars * mf_names,
    },
    'output': {
        'var_names': TARGET[0],
        'n_classes': 1,
    },
}

canfis = CANFIS(
    variables,
    'gaussian',
    and_operator=and_op,
    nn_layers=2,
    nn_neurons=8
).to(device)

# %% [markdown]
# Defining the loss function and optimizer:

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(canfis.parameters(), lr=0.001)

# %% [markdown]
# Training the model:

# %%
epochs = 100
train_losses, val_losses = [], []

for epoch in range(epochs):
    canfis.train()
    train_loss = 0.0

    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        y_pred = canfis(x_batch)
        loss = criterion(y_pred, y_batch.flatten())
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    canfis.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            y_pred = canfis(x_batch)
            loss = criterion(y_pred, y_batch.flatten())
            val_loss += loss.item()

    val_loss /= len(val_loader)
    val_losses.append(val_loss)

    if epoch % 10 == 9:
        print(f'Epoch {epoch+1}/{epochs}: train_loss: {train_loss:.4f} validation_loss {val_loss:.4f}')
# Out:
# Epoch 10/100: train_loss: 0.0042 validation_loss 0.0045
# Epoch 20/100: train_loss: 0.0028 validation_loss 0.0062
# Epoch 30/100: train_loss: 0.0027 validation_loss 0.0071
# Epoch 40/100: train_loss: 0.0027 validation_loss 0.0073
# Epoch 50/100: train_loss: 0.0031 validation_loss 0.0069
# Epoch 60/100: train_loss: 0.0032 validation_loss 0.0072
# Epoch 70/100: train_loss: 0.0024 validation_loss 0.0069
# Epoch 80/100: train_loss: 0.0029 validation_loss 0.0062
# Epoch 90/100: train_loss: 0.0028 validation_loss 0.0063
# Epoch 100/100: train_loss: 0.0024 validation_loss 0.0064

# %% [markdown]
# Plotting the loss and validation curve:

# %%
plt.plot(train_losses, label='Train')
plt.plot(val_losses, label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Curves')
plt.show()

# %% [markdown]
# Calculating the RMSE of the model

# %%
canfis.eval()
test_loss = 0.0

with torch.no_grad():
    for x_batch, y_batch in test_loader:
        y_pred = canfis(x_batch)
        y_pred *= y_test_max.item()
        y_batch *= y_test_max.item()
        mse = torch.mean((y_pred - y_batch.flatten()) ** 2)
        test_loss += mse.item()

rmse = torch.sqrt(torch.tensor(test_loss / len(test_loader)))

print(f"RMSE: {rmse.item():.4f}")
# Out:
# RMSE: 502.7500

# %% [markdown]
# Plotting the membership functions of the model:

# %%
fig, ax = canfis.plot_var(FEATURES[0])
plt.show()

# %% [markdown]
# The following plot depicts the projection of the fuzzy rules into two variables, with the fuzzy sets on the side of the plot.

# %%
fig, axes = canfis.plot_rules(FEATURES[:2], thr=0.8)
plt.show()

# %% [markdown]
# Visualizing the mean normalized activation of the rules, with the `.rule_activations()` method:

# %%
names = [f'{i}' for i in range(27)]

fig, ax = plt.subplots()

ax.bar(names, canfis.rule_activations(x_test).mean(dim=0).detach())

ax.set_xticks(range(len(names)))
ax.set_xticklabels(names, rotation=45)
ax.set_xlabel('Rules')
ax.set_ylabel('Mean Normalized Rule Activation')
ax.set_title('Histogram of Mean Normalized Rule Activation')

plt.show()

# %% [markdown]
# ## Classification

# %% [markdown]
# Now, we are going to perform a classification problem.

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Loading the dataset:

# %%
SEED = 10
torch.manual_seed = SEED

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"

df = pd.read_csv(url)
df = df.dropna()

FEATURES = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
TARGET = ['species']

x = df[FEATURES].values
y = df[TARGET].values

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y.ravel())

# %% [markdown]
# Train, test and validation split:

# %%
x, index = np.unique(x, axis=0, return_index=True)
y = y[index]

x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.4, random_state=SEED)
x_test, x_val, y_test, y_val = train_test_split(x_temp, y_temp, test_size=0.5, random_state=SEED)

x_train = torch.tensor(x_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
x_test = torch.tensor(x_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.long)
x_val = torch.tensor(x_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.long)

x_train_max = x_train.max(dim=0, keepdim=True)[0]
x_test_max = x_test.max(dim=0, keepdim=True)[0]
x_val_max = x_val.max(dim=0, keepdim=True)[0]

x_train /= x_train_max
x_test /= x_test_max
x_val /= x_val_max

# %% [markdown]
# Creating the DataLoaders:

# %%
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# Instantiating the model:

# %%
n_vars = 4
mf_names = [['L', 'M', 'H']]

variables = {
    'inputs': {
        'n_sets': n_vars * [3],
        'uod': n_vars * [(0, 1)],
        'var_names': FEATURES,
        'mf_names': n_vars * mf_names,
    },
    'output': {
        'var_names': ['Adelie', 'Chinstrap', 'Gentoo'],
        'n_classes': len(label_encoder.classes_),
    },
}

canfis = CANFIS(
    variables,
    'gaussian',
    and_operator=and_op,
    nn_layers=2,
    nn_neurons=8
).to(device)

# %% [markdown]
# Defining the loss and the optimizer:

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(canfis.parameters(), lr=0.001)

# %% [markdown]
# Training the model:

# %%
epochs = 100
train_losses, val_losses = [], []

for epoch in range(epochs):
    canfis.train()
    train_loss = 0.0

    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        y_pred = canfis(x_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    canfis.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            y_pred = canfis(x_batch)
            loss = criterion(y_pred, y_batch)
            val_loss += loss.item()

    val_loss /= len(val_loader)
    val_losses.append(val_loss)

    if epoch % 10 == 9:
        print(f'Epoch {epoch+1}/{epochs}: train_loss: {train_loss:.4f} validation_loss {val_loss:.4f}')
# Out:
# Epoch 10/100: train_loss: 0.0122 validation_loss 0.2499
# Epoch 20/100: train_loss: 0.0588 validation_loss 0.2423
# Epoch 30/100: train_loss: 0.0030 validation_loss 0.3883
# Epoch 40/100: train_loss: 0.0013 validation_loss 0.4985
# Epoch 50/100: train_loss: 0.0012 validation_loss 0.5577
# Epoch 60/100: train_loss: 0.0006 validation_loss 0.6264
# Epoch 70/100: train_loss: 0.0004 validation_loss 0.6506
# Epoch 80/100: train_loss: 0.0003 validation_loss 0.7005
# Epoch 90/100: train_loss: 0.0002 validation_loss 0.8001
# Epoch 100/100: train_loss: 0.0001 validation_loss 0.7734

# %% [markdown]
# Evaluating the performance:

# %%
with torch.no_grad():
    y_pred = canfis(x_test)
    y_pred = torch.argmax(y_pred, dim=1)
    accuracy = accuracy_score(y_test.numpy(), y_pred.numpy())
    print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 1.0000

# %% [markdown]
# Plotting the confusion matrix:

# %%
true_labels = y_test.numpy()
predicted_labels = y_pred.numpy()

cm = confusion_matrix(true_labels, predicted_labels)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='viridis')
plt.show()
